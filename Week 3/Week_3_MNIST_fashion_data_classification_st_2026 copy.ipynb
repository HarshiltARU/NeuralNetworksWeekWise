# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Neural Computing and Deep Learning </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-3 </h1> </html>

# %% [markdown]
# <html> <h2 style="font-style:italic; color:blue;"> MNIST Fashion Dataset Application with Keras </h2> </html>
#
#
# This is a sample image classification tutorial with the MNIST fashion image dataset.

# %%
# Your code to import TensorFlow
# Your code to import Keras
# Your code to import Numpy
import tensorflow as tf
from tensorflow import keras
import numpy as np
# ...
# ...
# ...

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.20.0

# %% [markdown]
# ### Import the Fashion MNIST dataset
# This guide uses the Fashion MNIST dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen below.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and load the Fashion MNIST data directly from TensorFlow:

# %% [markdown]
# _______________![image.png](attachment:6aaa7fce-b88a-4518-ae41-6c215f5d21a9.png)

# %%
from IPython.display import display, Image
myImage = Image('fashion-mnist-sprite.png');
myImage
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1090, in Image._repr_mimebundle_(self, include, exclude)
#    1088 if self.embed:
#    1089     mimetype = self._mimetype
# -> 1090     data, metadata = self._data_and_metadata(always_both=True)
#    1091     if metadata:
#    1092         metadata = {mimetype: metadata}
#
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1102, in Image._data_and_metadata(self, always_both)
#    1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
# -> 1102     raise FileNotFoundError(
#    1103         "No such file or directory: '%s'" % (self.data)) from e
#    1104 md = {}
#    1105 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'fashion-mnist-sprite.png'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1100, in Image._data_and_metadata(self, always_both)
#    1099 try:
# -> 1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1122, in Image._repr_png_(self)
#    1120 def _repr_png_(self):
#    1121     if self.embed and self.format == self._FMT_PNG:
# -> 1122         return self._data_and_metadata()
#
# File ~/tf310_clean/lib/python3.13/site-packages/IPython/core/display.py:1102, in Image._data_and_metadata(self, always_both)
#    1100     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1101 except TypeError as e:
# -> 1102     raise FileNotFoundError(
#    1103         "No such file or directory: '%s'" % (self.data)) from e
#    1104 md = {}
#    1105 if self.metadata:
#
# FileNotFoundError: No such file or directory: 'fashion-mnist-sprite.png'

# %% [markdown]
# _______________![image.png](attachment:9ec5b250-fbfc-4bad-9b16-eff3c273bcf8.png)

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# * The `train_images` and `train_labels` arrays are the *training set*—the data the model uses to learn.
# * The model is tested against the *test set*, the `test_images`, and `test_labels` arrays.
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The *labels* are an array of integers, ranging from 0 to 9. These correspond to the *class* of clothing the image represents:
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>

# %% [markdown]
# ![image.png](attachment:17b0cdfe-be9d-4c3e-95b6-3ab7a8c7d7f4.png)
# RGB grayscale Model

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, 
# store them here to use later when plotting the images:

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Explore the data
#
# Let's explore the format of the dataset before training the model. The following shows there are 60,000 images in the training set, with each image represented as 28 x 28 pixels:

# %%
# Your code to print the shape of the training images
train_images.shape
# ...
# Out:
# (60000, 28, 28)

# %% [markdown]
# Likewise, there are 60,000 labels in the training set:

# %%
# Your code to print the length of train labels
len(train_labels)
# ...
# Out:
# 60000

# %% [markdown]
# Each label is an integer between 0 and 9:

# %%
# Your code to print the training labels
train_labels
# ....
# Out:
# array([9, 0, 0, ..., 3, 0, 5], shape=(60000,), dtype=uint8)

# %% [markdown]
# There are 10,000 images in the test set. Again, each image is represented as 28 x 28 pixels:

# %%
# Your code to print the shape of the test set images
test_images.shape
# ...
# Out:
# (10000, 28, 28)

# %% [markdown]
# And the test set contains 10,000 images labels:

# %%
# Your code to print the length of the test labels
len(test_labels)
# ...
# Out:
# 10000

# %% [markdown]
# ### Preprocess the data
#
# The data must be preprocessed before training the network. If you inspect the first image in the training set, you will see that the pixel values fall in the range of 0 to 255:

# %% [markdown]
# __________________![image.png](attachment:acecface-b2bb-452c-936b-4c5dcc2fa6ff.png)

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# _________![image.png](attachment:c4637407-d02d-4dd0-882c-c7b79de9f015.png)

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ________![image.png](attachment:9c49c025-7c6b-47bc-9bc3-b9c743f8cd7e.png)

# %%
np.set_printoptions(precision = 1, floatmode = 'fixed')
train_images[[0],:10,16]
# Out:
# array([[  0,   0,   0,  73, 127, 176, 207, 218, 233, 223]], dtype=uint8)

# %% [markdown]
# ![image.png](attachment:ba07552f-54b3-4ecd-b135-c0e95a093590.png)

# %% [markdown]
# Scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, divide the values by 255. It's important that the *training set* and the *testing set* be preprocessed in the same way:

# %% [markdown]
# _____________![image.png](attachment:79f24c94-e19b-4151-b54e-b1e91f6ae89e.png)

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %% [markdown]
# To verify that the data is in the correct format and that you're ready to build and train the network, let's display the first 25 images from the *training set* and display the class name below each image.

# %% [markdown]
# _______________![image.png](attachment:2dc74140-d75b-4e1e-b6d5-58acf109fa66.png)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap = plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# <html> <h2 style="font-style:bold; color:blue;"> Build the model </h2> </html>
#
#
# Building the neural network requires configuring the layers of the model, then compiling the model.

# %% [markdown]
# Develop a a neural network model of your choice i.e. number of layers and activation function. Remember the input is a 2-D so you need to flatten the input.
#
# The first layer in this network, keras.layers.Flatten, should transform the format of the images from a two-dimensional array (of 28 by 28 pixels) to a one-dimensional array (of 28 * 28 = 784 pixels). Think of this layer as unstacking rows of pixels in the image and lining them up. This layer has no parameters to learn; it only reformats the data.

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(28, 28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# _____________![image.png](attachment:30102271-6a92-4d21-98ff-e9ab0f31d535.png)

# %%
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 235,146 (918.54 KB)
#  Trainable params: 235,146 (918.54 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# The result will be different, as your particular unique model should be demonstrated here

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Compile the model </h3> </html>
#
# Before the model is ready for training, it needs a few more settings. These are added during the model's *compile* step:
#
# * *Loss function* —This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.
# * *Optimizer* —This is how the model is updated based on the data it sees and its loss function.
# * *Metrics* —Used to monitor the training and testing steps. The following example uses *accuracy*, the fraction of the images that are correctly classified.
#
#
# We have used 'adam' optimizer. Try other optimizer functions. Use Keras API as a reference

# %% [markdown]
# _____________________![image.png](attachment:7efae15a-a67d-4540-8fba-b3fbb0a4b618.png)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;"> Train the model </h3> </html>
#
# Training the neural network model requires the following steps:
#
# 1. Feed the training data to the model. In this example, the training data is in the `train_images` and `train_labels` arrays.
# 2. The model learns to associate images and labels.
# 3. You ask the model to make predictions about a test set—in this example, the `test_images` array.
# 4. Verify that the predictions match the labels from the `test_labels` array.

# %% [markdown]
# #### Feed the model
#
# To start training,  call the `model.fit` method—so called because it "fits" the model to the training data:
#
# If you use your laptop without GPU, reduce epochs, number:  epochs=20

# %% [markdown]
# _______________![image.png](attachment:ee364c37-e0a4-4ee0-898a-0837a1e22111.png)

# %%
model.fit(train_images, train_labels, epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8302 - loss: 0.4723
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8690 - loss: 0.3572
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8802 - loss: 0.3238
# Epoch 4/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8895 - loss: 0.2993
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8940 - loss: 0.2827
# Epoch 6/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8995 - loss: 0.2680
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9032 - loss: 0.2567
# Epoch 8/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9078 - loss: 0.2433
# Epoch 9/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9110 - loss: 0.2340
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9141 - loss: 0.2237
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9163 - loss: 0.2183
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9205 - loss: 0.2086
# Epoch 13/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9218 - loss: 0.2035
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9262 - loss: 0.1936
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9274 - loss: 0.1882
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9299 - loss: 0.1814
# Epoch 17/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9312 - loss: 0.1758
# Epoch 18/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9336 - loss: 0.1729
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9358 - loss: 0.1661
# Epoch 20/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9373 - loss: 0.1640
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9382 - loss: 0.1593
# Epoch 22/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9408 - loss: 0.1524
# Epoch 23/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9421 - loss: 0.1512
# Epoch 24/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9438 - loss: 0.1470
# Epoch 25/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9466 - loss: 0.1398

# %%
history = model.fit(train_images, train_labels, epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9464 - loss: 0.1390
# Epoch 2/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9476 - loss: 0.1352
# Epoch 3/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9497 - loss: 0.1301
# Epoch 4/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9506 - loss: 0.1288
# Epoch 5/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9525 - loss: 0.1244
# Epoch 6/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9535 - loss: 0.1221
# Epoch 7/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9538 - loss: 0.1199
# Epoch 8/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9543 - loss: 0.1189
# Epoch 9/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9557 - loss: 0.1138
# Epoch 10/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9560 - loss: 0.1142
# Epoch 11/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9568 - loss: 0.1121
# Epoch 12/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9578 - loss: 0.1119
# Epoch 13/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9595 - loss: 0.1037
# Epoch 14/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9598 - loss: 0.1045
# Epoch 15/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9611 - loss: 0.1008
# Epoch 16/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9613 - loss: 0.1002
# Epoch 17/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9617 - loss: 0.0997
# Epoch 18/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9621 - loss: 0.0964
# Epoch 19/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9634 - loss: 0.0957
# Epoch 20/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9637 - loss: 0.0937
# Epoch 21/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9653 - loss: 0.0891
# Epoch 22/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9647 - loss: 0.0924
# Epoch 23/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9657 - loss: 0.0910
# Epoch 24/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9665 - loss: 0.0877
# Epoch 25/25
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9684 - loss: 0.0836

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed.

# %% [markdown]
# ________________________![image.png](attachment:f88c6afd-be96-4d92-a83d-2c73fb4a196d.png)

# %%
import matplotlib.pyplot as plt

history_dict = history.history
Accuracy = history_dict['accuracy']
plt.figure(num=1, figsize=(15,7))
plt.plot(Accuracy, 'bo', label='Training accuracy') 
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #### Evaluate accuracy
#
# Next, compare how the model performs on the test dataset:

# %% [markdown]
# _________![image.png](attachment:5e783f36-655b-4919-b021-fc7d9d32358e.png)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose = 2)
print('\nTest accuracy:' ,test_acc)
# Out:
# 313/313 - 0s - 693us/step - accuracy: 0.8905 - loss: 0.6930
#
# Test accuracy: 0.890500009059906

# %% [markdown]
# ### Make predictions
#
# With the model trained, you can use it to make predictions about some images.

# %% [markdown]
# ______________![image.png](attachment:86e8214a-634a-4ce8-877a-29c71f2fab42.png)

# %%
predictions = model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 392us/step

# %% [markdown]
# Here, the model has predicted the label for each image in the testing set. Let's take a look at the first prediction:

# %% [markdown]
# ___________![image.png](attachment:538aaa3b-3457-4fc1-b87c-7bc33e4ff7d8.png)

# %%
predictions[0]
# Out:
# array([8.5e-17, 1.7e-13, 1.2e-20, 8.4e-21, 3.9e-19, 5.0e-07, 2.6e-19,
#        5.6e-07, 8.6e-20, 1.0e+00], dtype=float32)

# %% [markdown]
# A prediction is an array of 10 numbers. They represent the model's "confidence" that the image corresponds to each of the 10 different articles of clothing. You can see which label has the highest confidence value:

# %% [markdown]
# _________![image.png](attachment:8338d0b2-8ad6-49f1-8f14-358d25c25780.png)

# %%
np.argmax(predictions[0])
# Out:
# np.int64(9)

# %% [markdown]
# So, the model is most confident that this image is an ankle boot, or `class_names[9]`. Examining the test label shows that this classification is correct:

# %% [markdown]
# ________![image.png](attachment:3128ce46-d578-4434-bf93-deaed5bc0127.png)

# %%
test_labels[0]
# Out:
# np.uint8(9)

# %%
test_labels[0]
# Out:
# np.uint8(9)

# %% [markdown]
# Graph this to look at the full set of 10 class predictions.

# %% [markdown]
# <html> <h4 style="font-style:italic; color:blue;"> Just run the next cell using 'Ctrl' + 'Enter' </h4> </html>

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# ### Verify predictions
#
# With the model trained, you can use it to make predictions about some images.

# %% [markdown]
# Let's look at the 0th image, predictions, and prediction array. Correct prediction labels are blue and incorrect prediction labels are red. The number gives the percentage (out of 100) for the predicted label.

# %% [markdown]
# ____________![image.png](attachment:6aaa3cd3-1bac-4b69-ad9d-f6f497c50a6c.png)

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot (1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot (1,2,2)
plot_value_array(i, predictions[i], test_labels) 
plt.show()

# %% [markdown]
# Plot any other image

# %%
# Your code to plot any other image and confidense score of your choise
i = 14
plt.figure(figsize=(6,3))
plt.subplot (1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot (1,2,2)
plot_value_array(i, predictions[i], test_labels) 
plt.show()
# ...
# ...

# %%
# Plot several images with their predictions.
# In the next cell, you need to plot the first 15 images in the following format.

# Use the sample code of the plots provided in this tutorial. Hint - You need to
# use subplots, for loop, etc..

# Plot the first X test images, their predicted labels, and the true labels.

# Color correct predictions in blue and incorrect predictions in red.

# %% [markdown]
# ________![image.png](attachment:c255e28d-7dfb-473e-8729-fba2e4559b98.png)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows * num_cols

plt.figure(figsize=(2*2*num_cols, 2*num_rows))

for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i + 1)
    plot_image(i, predictions[i], test_labels, test_images)

    plt.subplot(num_rows, 2*num_cols, 2*i + 2)
    plot_value_array(i, predictions[i], test_labels)

plt.tight_layout()
plt.show()

# %%
#
# Your code to plot first 20 predictions in the above format.
#
# ...
# ...

# %% [markdown]
# <html> <h2 style="font-style:bold; color:blue;"> Use the trained model </h2> </html>
# (Advanced part)
#
# Finally, use the trained model to make a prediction about a single image.

# %% [markdown]
# ____![image.png](attachment:506b1a29-f66c-4b9e-b7ef-846fcdba8d18.png)

# %%
img = test_images[1]
print(img.shape)
# Out:
# (28, 28)

# %% [markdown]
# `tf.keras` models are optimized to make predictions on a *batch*, or collection, of examples at once. Accordingly, even though you're using a single image, you need to add it to a list:

# %% [markdown]
# _________![image.png](attachment:21faaea8-7f5c-42e9-988a-ebfbeaceafd2.png)

# %%
img = (np.expand_dims(img,0))
print(img.shape)
# Out:
# (1, 28, 28)

# %% [markdown]
# Now predict the correct label for this image:

# %% [markdown]
# _________![image.png](attachment:29b2ab4a-58db-4241-8024-2198cf59d216.png)

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [[2.7e-07 5.8e-14 1.0e+00 5.0e-08 1.9e-05 3.4e-15 6.1e-04 6.9e-32 2.3e-16
#   2.5e-22]]

# %% [markdown]
# ___________![image.png](attachment:5faa0638-6784-411b-b80d-83af3c87e3c3.png)

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %% [markdown]
# `model.predict` returns a list of lists—one list for each image in the batch of data. Grab the predictions for our (only) image in the batch:

# %% [markdown]
# _________![image.png](attachment:774e043b-a83f-4f97-8824-1ef8e0259325.png)

# %%
np.argmax(predictions_single[0])
# Out:
# np.int64(2)

# %% [markdown]
# <html> <h2 style="font-style:bold; color:red;"> Lab Logbook requirements </h2> </html>
#
# ### Please record your model's accuracy (test data) and a summary of its development. You can obtain the model summary using the model.summary() method. The API for obtaining the model summary is defined in the following link:
#
# ### https://keras.io/api/models/model/#summary-method
#
# ### Ensure that no code or other information is added to the logbook and that only required information is present.  Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.

# %% [markdown]
# <html> <h4 style="font-style:bold; color:red;"> NOTE: DO NOT FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB. </h4> </html>
